# %% [markdown]
# <a href="https://colab.research.google.com/github/lim4373/Ai-Deep-Learning/blob/main/%EB%B8%94%EB%9E%99%ED%99%80%2C%EC%9A%B0%EC%A3%BC%EC%9D%80%ED%95%98_dt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터를 불러와 데이터 형식 확인하기

# %%
import astropy.io.fits as fits
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
from google.colab import drive
drive.mount('/content/drive')


image_file =  '/content/drive/MyDrive/Colab Notebooks/hlsp_hlastarclusters_hst_acs-wfc_ngc4038-10188-10_f814w_v1_sci_sci.fits'

galaxy_data = fits.open(image_file)
print(galaxy_data.info())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Filename: /content/drive/MyDrive/Colab Notebooks/hlsp_hlastarclusters_hst_acs-wfc_ngc4038-10188-10_f814w_v1_sci_sci.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     496   ()
#   1  SCI           1 ImageHDU       143   (5950, 5950)   float32
# None

# %%
image = galaxy_data[1].data
header = galaxy_data[1].header

print("info", header["PHOTMODE"])
# ACS WFC1 F814W MJD#52519.9608
# 촬영기기   필터    줄리안데이
print("deg/pixel", header["CD2_2"])
# 1픽셀당 각도
# Out:
# info ACS WFC1 F814W MJD#53207.3010
# deg/pixel 1.38888888888888e-05

# %%
plt.figure(figsize=(8,8))
plt.imshow(image, origin='lower', vmax = max_value, vmin = min_value)
# cmap='gray' : 흑백으로 연출
# origin='lower' : 좌표축의 좌측 아래를 (0,0)으로 설정
plt.show()

# %%
NGC4038_image = np.array(image)

max_value = np.percentile(image, 99)
min_value = np.percentile(image, 60)

plt.figure(figsize=(8,8))
plt.imshow(image, cmap='gray', origin='lower', vmax = max_value, vmin = min_value)
# cmap='gray' : 흑백으로 연출
# origin='lower' : 좌표축의 좌측 아래를 (0,0)으로 설정
plt.show()

# %%
NGC4038_image = np.array(image)

max_value = np.percentile(image, 99)
min_value = np.percentile(image, 60)

plt.figure(figsize=(8,8))
plt.imshow(image, cmap='PuBu', origin='lower', vmax = max_value, vmin = min_value)
# cmap='gray' : 흑백으로 연출
# origin='lower' : 좌표축의 좌측 아래를 (0,0)으로 설정
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.imshow(image, cmap='afmhot', origin='lower', vmax = max_value, vmin = min_value)
# cmap='gray' : 흑백으로 연출
# origin='lower' : 좌표축의 좌측 아래를 (0,0)으로 설정
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.imshow(image, cmap='winter', origin='lower', vmax = max_value, vmin = min_value)
# cmap='gray' : 흑백으로 연출
# origin='lower' : 좌표축의 좌측 아래를 (0,0)으로 설정
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.imshow(image, cmap='copper', origin='lower', vmax = max_value, vmin = min_value)
# cmap='gray' : 흑백으로 연출
# origin='lower' : 좌표축의 좌측 아래를 (0,0)으로 설정
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.imshow(image, cmap='binary', origin='lower', vmax = max_value, vmin = min_value)
# cmap='gray' : 흑백으로 연출
# origin='lower' : 좌표축의 좌측 아래를 (0,0)으로 설정
plt.show()

# %%
NGC4038_image = np.array(image)

max_value = np.percentile(image, 99)
min_value = np.percentile(image, 60)

plt.figure(figsize=(10,4))


plt.subplot(1,4,1)
plt.imshow(image,cmap='gray', origin='lower', vmax = max_value, vmin = min_value)

plt.subplot(1,4,2)
plt.imshow(image,cmap='PuBu', origin='lower', vmax = max_value, vmin = min_value)


plt.subplot(1,4,3)
plt.imshow(image,cmap='afmhot', origin='lower', vmax = max_value, vmin = min_value)

plt.subplot(1,4,4)
plt.imshow(image,cmap='bone', origin='lower', vmax = max_value, vmin = min_value)
